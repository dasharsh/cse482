# %%
import pandas as pd
import numpy as np
from scipy.sparse import csr_matrix
import sklearn
from sklearn.decomposition import TruncatedSVD
import matplotlib.pyplot as plt
from sklearn.cross_validation import train_test_split

artist_list = [i.strip().split('\t') for i in open('out.txt', 'r', encoding="utf8").readlines()]
artist_df = pd.DataFrame(artist_list, columns = ['ArtistID', 'ArtistName'])
artist_df['ArtistID'] = artist_df['ArtistID'].apply(pd.to_numeric)

#print(artist_df.head())

rating = pd.read_csv('finalUserData.csv', sep=',', header=None, dtype=int)
rating.columns = ['user_id', 'ArtistID', 'Rating']
#print(rating.head())

rat = pd.merge(rating, artist_df, on='ArtistID')
columns = ['ArtistID', 'ArtistName', 'user_id', 'Rating']
#print(rat.head())

rat = rat.dropna(axis=0, subset=['ArtistName'])
artist_ratingCount = (rat.groupby(by = ['ArtistName'])['Rating'].
                     count().
                     reset_index().
                     rename(columns = {'Rating': 'totalRatingCount'})
                     [['ArtistName', 'totalRatingCount']]
                     )
artist_ratingCount.head()
# Out:
#      ArtistName  totalRatingCount
# 0           !!!                 6
# 1      "D" Lil'                 2
# 2  '68 Comeback                 1
# 3  'Til Tuesday                41
# 4    (Hed) P.E.                30

# %%
#Class for Popularity based Recommender System model
class popularity_recommender_py():
    def __init__(self):
        self.train_data = None
        self.user_id = None
        self.item_id = None
        self.popularity_recommendations = None
        
    #Create the popularity based recommender system model
    def create(self, train_data, user_id, item_id):
        self.train_data = train_data
        self.user_id = user_id
        self.item_id = item_id

        #Get a count of user_ids for each unique song as recommendation score
        train_data_grouped = train_data.groupby([self.item_id]).agg({self.user_id: 'count'}).reset_index()
        train_data_grouped.rename(columns = {'user_id': 'score'},inplace=True)
    
        #Sort the songs based upon recommendation score
        train_data_sort = train_data_grouped.sort_values(['score', self.item_id], ascending = [0,1])
    
        #Generate a recommendation rank based upon score
        train_data_sort['Rank'] = train_data_sort['score'].rank(ascending=0, method='first')
        
        #Get the top 10 recommendations
        self.popularity_recommendations = train_data_sort.head(10)

    #Use the popularity based recommender system model to
    #make recommendations
    def recommend(self, user_id):    
        user_recommendations = self.popularity_recommendations
        
        #Add user_id column for which the recommendations are being generated
        user_recommendations['user_id'] = user_id
    
        #Bring user_id column to the front
        cols = user_recommendations.columns.tolist()
        cols = cols[-1:] + cols[:-1]
        user_recommendations = user_recommendations[cols]
        
        return user_recommendations
    

#Class for Item similarity based Recommender System model
class item_similarity_recommender_py():
    def __init__(self):
        self.train_data = None
        self.user_id = None
        self.item_id = None
        self.cooccurence_matrix = None
        self.songs_dict = None
        self.rev_songs_dict = None
        self.item_similarity_recommendations = None
        
    #Get unique items (songs) corresponding to a given user
    def get_user_items(self, user):
        user_data = self.train_data[self.train_data[self.user_id] == user]
        user_items = list(user_data[self.item_id].unique())
        
        return user_items
        
    #Get unique users for a given item (song)
    def get_item_users(self, item):
        item_data = self.train_data[self.train_data[self.item_id] == item]
        item_users = set(item_data[self.user_id].unique())
            
        return item_users
        
    #Get unique items (songs) in the training data
    def get_all_items_train_data(self):
        all_items = list(self.train_data[self.item_id].unique())
            
        return all_items
        
    #Construct cooccurence matrix
    def construct_cooccurence_matrix(self, user_songs, all_songs):
            
        ####################################
        #Get users for all songs in user_songs.
        ####################################
        user_songs_users = []        
        for i in range(0, len(user_songs)):
            user_songs_users.append(self.get_item_users(user_songs[i]))
            
        ###############################################
        #Initialize the item cooccurence matrix of size 
        #len(user_songs) X len(songs)
        ###############################################
        cooccurence_matrix = np.matrix(np.zeros(shape=(len(user_songs), len(all_songs))), float)
           
        #############################################################
        #Calculate similarity between user songs and all unique songs
        #in the training data
        #############################################################
        for i in range(0,len(all_songs)):
            #Calculate unique listeners (users) of song (item) i
            songs_i_data = self.train_data[self.train_data[self.item_id] == all_songs[i]]
            users_i = set(songs_i_data[self.user_id].unique())
            
            for j in range(0,len(user_songs)):       
                    
                #Get unique listeners (users) of song (item) j
                users_j = user_songs_users[j]
                    
                #Calculate intersection of listeners of songs i and j
                users_intersection = users_i.intersection(users_j)
                
                #Calculate cooccurence_matrix[i,j] as Jaccard Index
                if len(users_intersection) != 0:
                    #Calculate union of listeners of songs i and j
                    users_union = users_i.union(users_j)
                    
                    cooccurence_matrix[j,i] = float(len(users_intersection))/float(len(users_union))
                else:
                    cooccurence_matrix[j,i] = 0
                    
        
        return cooccurence_matrix

    
    #Use the cooccurence matrix to make top recommendations
    def generate_top_recommendations(self, user, cooccurence_matrix, all_songs, user_songs):
        print("Non zero values in cooccurence_matrix :%d" % np.count_nonzero(cooccurence_matrix))
        
        #Calculate a weighted average of the scores in cooccurence matrix for all user songs.
        user_sim_scores = cooccurence_matrix.sum(axis=0)/float(cooccurence_matrix.shape[0])
        user_sim_scores = np.array(user_sim_scores)[0].tolist()
 
        #Sort the indices of user_sim_scores based upon their value
        #Also maintain the corresponding score
        sort_index = sorted(((e,i) for i,e in enumerate(list(user_sim_scores))), reverse=True)
    
        #Create a dataframe from the following
        columns = ['user_id', 'ArtistName', 'score', 'rank']
        #index = np.arange(1) # array of numbers for the number of samples
        df = pandas.DataFrame(columns=columns)
         
        #Fill the dataframe with top 10 item based recommendations
        rank = 1 
        for i in range(0,len(sort_index)):
            if ~np.isnan(sort_index[i][0]) and all_songs[sort_index[i][1]] not in user_songs and rank <= 10:
                df.loc[len(df)]=[user,all_songs[sort_index[i][1]],sort_index[i][0],rank]
                rank = rank+1
        
        #Handle the case where there are no recommendations
        if df.shape[0] == 0:
            print("The current user has no songs for training the item similarity based recommendation model.")
            return -1
        else:
            return df
 
    #Create the item similarity based recommender system model
    def create(self, train_data, user_id, item_id):
        self.train_data = train_data
        self.user_id = user_id
        self.item_id = item_id

    #Use the item similarity based recommender system model to
    #make recommendations
    def recommend(self, user):
        
        ########################################
        #A. Get all unique songs for this user
        ########################################
        user_songs = self.get_user_items(user)    
            
        print("No. of unique artists for the user: %d" % len(user_songs))
        
        ######################################################
        #B. Get all unique items (songs) in the training data
        ######################################################
        all_songs = self.get_all_items_train_data()
        
        print("no. of unique artists in the training set: %d" % len(all_songs))
         
        ###############################################
        #C. Construct item cooccurence matrix of size 
        #len(user_songs) X len(songs)
        ###############################################
        cooccurence_matrix = self.construct_cooccurence_matrix(user_songs, all_songs)
        
        #######################################################
        #D. Use the cooccurence matrix to make recommendations
        #######################################################
        df_recommendations = self.generate_top_recommendations(user, cooccurence_matrix, all_songs, user_songs)
                
        return df_recommendations
    
    #Get similar items to given items
    def get_similar_items(self, item_list):
        
        user_songs = item_list
        
        ######################################################
        #B. Get all unique items (songs) in the training data
        ######################################################
        all_songs = self.get_all_items_train_data()
        
        print("no. of unique artists in the training set: %d" % len(all_songs))
         
        ###############################################
        #C. Construct item cooccurence matrix of size 
        #len(user_songs) X len(songs)
        ###############################################
        cooccurence_matrix = self.construct_cooccurence_matrix(user_songs, all_songs)
        
        #######################################################
        #D. Use the cooccurence matrix to make recommendations
        #######################################################
        user = ""
        df_recommendations = self.generate_top_recommendations(user, cooccurence_matrix, all_songs, user_songs)
         
        return df_recommendations

# %%
users = rat['user_id'].unique()
#print(len(users)) ## return 200 unique users

artists = rat['ArtistID'].unique()
#print(len(artists)) ## return 15939 unique artists

train_data, test_data = train_test_split(rat, test_size = 0.20, random_state=0)

pm = popularity_recommender_py()
pm.create(train_data, 'user_id', 'ArtistName')

# #user the popularity model to make some prediction
# print('For users the most popular (top 10 artists) artist recommendations are: ')
# print(pm.recommend(users[5]))

is_model = item_similarity_recommender_py()
is_model.create(train_data, 'user_id', 'ArtistName')

# %%
#Print the songs for the user in training data
for i in list(users):
    user_id = i
    user_items = is_model.get_user_items(user_id)
    #
    print("------------------------------------------------------------------------------------")
    print("Training data artists for the user userid: %s:" % user_id)
    print("------------------------------------------------------------------------------------")

    count = 0
    for user_item in user_items:
        print(user_item)
        count+=1
        if count >= 5:
            break
# Out:
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 1:
# ------------------------------------------------------------------------------------
# Drag-On
# Lina
# Aaliyah
# Seal
# Blackstreet
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 4:
# ------------------------------------------------------------------------------------
# Heather Headley
# Yellowcard
# Kelly Rowland
# Dirty
# Cypress Hill
# ------------------------------------------------------------------------------------
# Training data artists for the user userid:
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 65:
# ------------------------------------------------------------------------------------
# Dierks Bentley
# Bruce Cockburn
# Octoscope
# Joe Bonamassa
# Julieta Venegas
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 67:
# ------------------------------------------------------------------------------------
# Zion I
# Jay-Z
# Olivia Newton-John
# Juno Reactor
# Melissa Etheridge
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 68:
# ------------------------------------------------------------------------------------
# Michael Jackson
# Changing Faces
# K7
# Mary J. Blige
# N'Dea Davenport
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 70:
# ------------------------------------------------------------------------------------
# The Beautiful Mistake
# Tracy Chapman
# Peter Gabriel
# Damien Rice
# Deniece Williams
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 71:
# ------------------------------------------------------------------------------------
# SWV
# Horace Andy
# Sneaker Pimps
# Ralph Tresvant
# The Sundays
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 72:
# ------------------------------------------------------------------------------------
# The Kinks
# 50 Cent
# Looking Glass
# Craig David
# REO Speedwagon
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 73:
# ------------------------------------------------------------------------------------
# Kelly Price
# Gene Pitney
# Mana
# Creedence Clearwater Revival
# Natas
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 75:
# ------------------------------------------------------------------------------------
# Sade
# Matchbox Twenty
# Linkin Park
# Krayzie Bone
# Hooverphonic
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 79:
# ------------------------------------------------------------------------------------
# Dilated Peoples
# Reel Big Fish
# Bowling For Soup
# Operation Ivy
# The Sex Pistols
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 81:
# ------------------------------------------------------------------------------------
# Uncle Kracker
# The Violent Femmes
# Chris Rock
# The Doobie Brothers
# The Celtic Rogues
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 82:
# ------------------------------------------------------------------------------------
# Angela Via
# Ray J
# Luther Vandross
# Genesis
# Asheru & Blue Black Of The Unspoken Heard
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 86:
# ------------------------------------------------------------------------------------
# Amanda Latona
# Changing Faces
# Tweet
# Soulfruit
# Missin' Linx
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 87:
# ------------------------------------------------------------------------------------
# Santana
# Quarashi
# Tweet
# 12 Stones
# Megadeth
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 90:
# ------------------------------------------------------------------------------------
# The White Stripes
# DJ Micro
# James Brown
# Jane's Addiction
# Wu-Tang Clan
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 91:
# ------------------------------------------------------------------------------------
# Orange 9mm
# Prymary Colorz
# Vitamin C
# Gene Autry
# Mass Appeal
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 96:
# ------------------------------------------------------------------------------------
# Ted Nugent
# Soundgarden
# Powerman 5000
# Motorhead
# Dead Or Alive
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 99:
# ------------------------------------------------------------------------------------
# Shania Twain
# Color Me Badd
# Evanescence
# Edwin McCain
# Pete Tong
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 100:
# ------------------------------------------------------------------------------------
# The Isley Brothers
# The Four Tops
# Elliott Smith
# Sade
# The Corrs
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 105:
# ------------------------------------------------------------------------------------
# Miranda Sex Garden
# Macy Gray
# Paula Cole
# Marcy Playground
# Whitesnake
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 108:
# ------------------------------------------------------------------------------------
# Phantom 45
# Keiko Matsui
# Stevie Wonder
# Moochie Mack
# Coldplay
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 110:
# ------------------------------------------------------------------------------------
# Chomsky
# Motley Crue
# Grind
# Willy DeVille
# George Harrison
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 112:
# ------------------------------------------------------------------------------------
# Euge Groove
# William Orbit
# Jeff Hanson
# DJ Sage
# Greg Adams
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 113:
# ------------------------------------------------------------------------------------
# News At Eleven
# Mannheim Steamroller
# Motochrist
# King Fleming
# Adrian Belew
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 117:
# ------------------------------------------------------------------------------------
# Tosca
# Gorillaz
# Good Charlotte
# Jaguares
# Hole
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 118:
# ------------------------------------------------------------------------------------
# The Hives
# Booker T.
# Russell Crowe & 30 Odd Foot Of Grunts
# Dixie Chicks
# Laura Branigan
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 119:
# ------------------------------------------------------------------------------------
# Mannheim Steamroller
# Tracy Bonham
# Alanis Morissette
# Van Morrison
# Supertramp
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 122:
# ------------------------------------------------------------------------------------
# Louie DeVito
# Jo Dee Messina
# Sasha Alexander
# Karen Young
# Gorillaz
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 123:
# ------------------------------------------------------------------------------------
# Julia Fordham
# The Strokes
# John Mayer
# The Roots
# Neil Diamond
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 125:
# ------------------------------------------------------------------------------------
# Sting
# Brian McKnight
# Frank Zappa
# Jesse Malin
# The Kingsmen
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 127:
# ------------------------------------------------------------------------------------
# Dishwalla
# Kate & Anna McGarrigle
# Pink Floyd
# Shonen Knife
# Nightwish
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 130:
# ------------------------------------------------------------------------------------
# Rush
# Harry Chapin
# George Strait
# The Federation
# Yngwie Malmsteen
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 133:
# ------------------------------------------------------------------------------------
# Buju Banton
# Starlings
# TRUSTcompany
# Las Ketchup
# After 7
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 134:
# ------------------------------------------------------------------------------------
# Smile Empty Soul
# Yoko Ono
# Pavement
# The Adverts
# Banco De Gaia
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 137:
# ------------------------------------------------------------------------------------
# Gorillaz
# Sawyer Brown
# ATB
# Gong
# Cowboy Junkies
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 138:
# ------------------------------------------------------------------------------------
# Steppenwolf
# Robert Earl Keen
# TRUSTcompany
# Howlin' Wolf
# Teddy Pendergrass
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 139:
# ------------------------------------------------------------------------------------
# Bow Wow
# Tracy Bonham
# Vikter Duplaix
# Afroman
# Art Of Noise
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 140:
# ------------------------------------------------------------------------------------
# Moby
# Mark Wills
# Heart
# Nivea
# Crowded House
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 145:
# ------------------------------------------------------------------------------------
# The Thompson Twins
# Cinderella
# Mike Ness
# Dizzy Gillespie
# U.S. Bombs
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 148:
# ------------------------------------------------------------------------------------
# Savatage
# Conway Twitty
# Japan
# Possessed
# Refused
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 150:
# ------------------------------------------------------------------------------------
# King Chango
# Scanner
# Wire
# Shadowy Men On A Shadowy...
# The Leaves
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 151:
# ------------------------------------------------------------------------------------
# Jewel
# Journey
# Aqua
# Michael Zentner
# Fat Joe
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 152:
# ------------------------------------------------------------------------------------
# The Emotions
# Bowling For Soup
# Cat Stevens
# The Pasties
# Vanessa Carlton
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 153:
# ------------------------------------------------------------------------------------
# Nickelback
# Jin
# Joe
# Fabolous
# El DeBarge
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 157:
# ------------------------------------------------------------------------------------
# Terri Clark
# Alabama
# Kenny Rogers
# INXS
# The Breeders
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 158:
# ------------------------------------------------------------------------------------
# Billy Joel
# Bread
# Further Seems Forever
# Tina Turner
# Blu Cantrell
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 160:
# ------------------------------------------------------------------------------------
# Sophie B. Hawkins
# Saliva
# Rufus
# Godsmack
# Radiohead
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 161:
# ------------------------------------------------------------------------------------
# Talking Heads
# Nerf Herder
# Jason Falkner
# Gordon Lightfoot
# Danzig
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 163:
# ------------------------------------------------------------------------------------
# Paul Simon
# Porno For Pyros
# They Might Be Giants
# The Corrs
# Eric Clapton
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 164:
# ------------------------------------------------------------------------------------
# Trace Adkins
# Soul For Real
# Pink
# Tony Toni Tone
# John B.
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 168:
# ------------------------------------------------------------------------------------
# Brian Setzer Orchestra
# Lydia Lunch
# Celldweller
# Funky Green Dogs
# Kate Jacobs
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 169:
# ------------------------------------------------------------------------------------
# Yaz
# Eve
# The All-American Rejects
# P. Diddy
# The (International) Noise Conspiracy
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 172:
# ------------------------------------------------------------------------------------
# Shania Twain
# Rammstein
# Eric Clapton
# Khia
# Save Ferris
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 173:
# ------------------------------------------------------------------------------------
# DJ Premier
# Thus Spoke Z
# Michael Stuart
# MC Solaar
# Daddy Freddy
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 175:
# ------------------------------------------------------------------------------------
# Sundial
# Women Of Faith
# Fefe Dobson
# Bush
# Twothirtyeight
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 180:
# ------------------------------------------------------------------------------------
# Suzanne Vega
# Hank Williams
# Genesis
# Handsome Boy Modeling School
# Phoebe Snow
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 181:
# ------------------------------------------------------------------------------------
# The Marshall Tucker Band
# John Michael Montgomery
# Joe Walsh
# Jay-Z
# Clay Walker
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 183:
# ------------------------------------------------------------------------------------
# Judy Garland
# Pennywise
# The Go-Go's
# Ja Rule
# Jade
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 185:
# ------------------------------------------------------------------------------------
# Sting
# Big Pun
# Emmylou Harris
# Jane's Addiction
# Jodeci
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 188:
# ------------------------------------------------------------------------------------
# Zao
# Grade
# Dee Snider
# Bad Brains
# Kut Klose
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 190:
# ------------------------------------------------------------------------------------
# R.E.M.
# Depeche Mode
# Boston
# George Carlin
# Prince
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 194:
# ------------------------------------------------------------------------------------
# Charlie Daniels Band
# Third Day
# John Lee Hooker
# English Chamber Orchestra
# Mint Condition
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 198:
# ------------------------------------------------------------------------------------
# Graham Parker
# Bill Engvall
# Nelly Furtado
# DMX
# Juvenile
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 2:
# ------------------------------------------------------------------------------------
# Matthew Ryan
# Rebecca Lynn Howard
# Digable Planets
# Aaron Tippin
# Crash Test Dummies
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 13:
# ------------------------------------------------------------------------------------
# Chris Rice
# Hegemonic
# Thanh Lam
# Eddie "Blues Man" Kirkland
# Blaque
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 20:
# ------------------------------------------------------------------------------------
# Liquid Tension Experiment
# Laura Nyro
# Jon Spencer Blues Explosion
# The Beat Farmers
# Propellerheads
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 25:
# ------------------------------------------------------------------------------------
# Atmosphere
# Cheech & Chong
# INXS
# Oyster Band
# Smokey Robinson
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 28:
# ------------------------------------------------------------------------------------
# Berline, Crary & Hickman
# Special EFX
# Jonatha Brooke
# The BoDeans
# Jimmy Eat World
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 32:
# ------------------------------------------------------------------------------------
# Jackson Browne
# The Suburbs
# Gary Burton
# REO Speedwagon
# Kruder & Dorfmeister
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 47:
# ------------------------------------------------------------------------------------
# DJ Sammy & Yanou
# NoFx
# John Digweed
# RZA
# Yukmouth
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 59:
# ------------------------------------------------------------------------------------
# The Fixx
# Mark Lewis
# Charles Feelgood
# Zydeco Hurricanes
# Hosea Leavy
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 66:
# ------------------------------------------------------------------------------------
# DJ Encore
# LL Cool J
# Seven Witches
# Coolio
# Cat Power
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 76:
# ------------------------------------------------------------------------------------
# Josh Groban
# Sense Field
# Floetry
# Donnie McClurkin
# Seven Mary Three
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 88:
# ------------------------------------------------------------------------------------
# Latimore
# The Milltown Brothers
# Veruca Salt
# Tears For Fears
# Marianne Faithfull
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 89:
# ------------------------------------------------------------------------------------
# Randy Travis
# T. Rex
# R.E.M.
# Tech N9ne
# Hot Hot Heat
# ------------------------------------------------------------------------------------
# Training data artists for the user userid:
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 98:
# ------------------------------------------------------------------------------------
# Jason Mraz
# DJ Micro
# MDFMK
# Jane's Addiction
# Andreas Vollenweider
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 135:
# ------------------------------------------------------------------------------------
# DJ Assault
# SWV
# DJ Shadow
# Ice Cube
# Ralph Tresvant
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 167:
# ------------------------------------------------------------------------------------
# Dropkick Murphys
# Gary Lucas
# Toad The Wet Sprocket
# Shakira
# The Clash
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 177:
# ------------------------------------------------------------------------------------
# Black Box Recorder
# Chad Kroeger
# Timelords
# Wilco
# Simian
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 200:
# ------------------------------------------------------------------------------------
# Ginuwine
# LeAnn Rimes
# OK Go
# Saigon Kick
# Clipse
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 8:
# ------------------------------------------------------------------------------------
# Boredoms
# NoFx
# Dottie Peoples
# Lemonheads
# Earth, Wind & Fire
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 11:
# ------------------------------------------------------------------------------------
# Still Breathing
# Vixtrola
# The Aqua Velvets
# Poison The Well
# A Flock Of Seagulls
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 14:
# ------------------------------------------------------------------------------------
# Mark Wills
# Lou Reed
# Jet
# The Clash
# The Police
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 15:
# ------------------------------------------------------------------------------------
# No Doubt
# Count Basic
# Alvin Lee
# From Autumn To Ashes
# The Mars Volta
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 22:
# ------------------------------------------------------------------------------------
# Collective Soul
# The Misfits
# Nick Cave & The Bad Seeds
# Queensryche
# Lisa Loeb
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 24:
# ------------------------------------------------------------------------------------
# Stone Sour
# Aaliyah
# Seal
# Natalie Imbruglia
# Queens Of The Stone Age
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 29:
# ------------------------------------------------------------------------------------
# Chingy
# King Missile
# Sasha & Digweed
# DJ Taylor
# Babyface
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 40:
# ------------------------------------------------------------------------------------
# Good Charlotte
# Goo Goo Dolls
# Rooney
# Richard Marx
# Alicia Keys
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 41:
# ------------------------------------------------------------------------------------
# Bad Brains
# The All-American Rejects
# From Autumn To Ashes
# Pavement
# At The Drive-In
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 43:
# ------------------------------------------------------------------------------------
# Pulp
# Avant
# SHeDAISY
# Peter Wolf
# Iron Maiden
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 45:
# ------------------------------------------------------------------------------------
# Travis
# The Federation
# Was (Not Was)
# Ashley MacIsaac
# BMF
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 49:
# ------------------------------------------------------------------------------------
# Supertramp
# The Yardbirds
# Possessed
# Pet Shop Boys
# Nine Inch Nails
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 55:
# ------------------------------------------------------------------------------------
# George Benson
# The Vapors
# Black Sabbath
# Uncle Kracker
# Wilson Phillips
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 62:
# ------------------------------------------------------------------------------------
# Culture
# Juno Reactor
# Orgy
# The Alkaline Trio
# Metallica
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 69:
# ------------------------------------------------------------------------------------
# Stagga Lee
# Fastball
# Propellerheads
# Corrosion Of Conformity
# Testament
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 78:
# ------------------------------------------------------------------------------------
# Ultra Nate
# Sunshine Anderson
# Lifehouse
# Coldplay
# The Ataris
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 80:
# ------------------------------------------------------------------------------------
# Doug Sahm
# Dropline
# Thomas Dolby
# Quicksand
# John Mayer
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 83:
# ------------------------------------------------------------------------------------
# The Great Kat
# The Nixons
# Randy Travis
# Catherine
# Urge Overkill
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 84:
# ------------------------------------------------------------------------------------
# Helmet
# Minor Threat
# Whitesnake
# Brian Jonestown Massacre
# Aimee Mann
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 95:
# ------------------------------------------------------------------------------------
# The Pixies
# Spice Girls
# Mos Def
# Concrete Blonde
# Joan Jett
# ------------------------------------------------------------------------------------
# Training data artists for the user userid:
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 92:
# ------------------------------------------------------------------------------------
# Miles Davis
# Boz Scaggs
# Vallejo
# George Benson
# Plastilina Mosh
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 111:
# ------------------------------------------------------------------------------------
# Mike Errico
# Chalee Tennison
# Television
# Melomane
# Speedealer
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 115:
# ------------------------------------------------------------------------------------
# Dionne Warwick
# Michelle Willson
# Gary Numan
# Christina Aguilera
# Slipknot
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 156:
# ------------------------------------------------------------------------------------
# Japan
# Simple Minds
# Twisted Sister
# Pink
# Jackson Browne
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 171:
# ------------------------------------------------------------------------------------
# New Order
# Socialburn
# Throwing Muses
# Queen
# Stacie Orrico
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 182:
# ------------------------------------------------------------------------------------
# The Clash
# Bobby Womack
# Pink
# Firehouse
# Orchestral Manoeuvres In The Dark
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 184:
# ------------------------------------------------------------------------------------
# Alicia Bridges
# Mountain
# Jimmie Dale Gilmore
# Marah
# Aaron Carter
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 195:
# ------------------------------------------------------------------------------------
# Rob Zombie
# The K.G.B.
# Red Hot Chili Peppers
# Turin Brakes
# The Moles
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 196:
# ------------------------------------------------------------------------------------
# The Cranberries
# The Moles
# Kenny Garrett
# David Sanborn
# Miles Davis
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 197:
# ------------------------------------------------------------------------------------
# Sons Of Champlin
# Buffalo Daughter
# Full Devil Jacket
# Reid Paley
# The Forty Fives
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 5:
# ------------------------------------------------------------------------------------
# Bananarama
# Fischerspooner
# Sanctus Real
# Jellyfish
# Kiss
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 9:
# ------------------------------------------------------------------------------------
# Jeff Midkiff
# Kim Gordon
# The Sonics
# Expose
# The Washdown
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 21:
# ------------------------------------------------------------------------------------
# Abiodun Oyewole
# Waylon Jennings
# Toni Braxton
# Moxy Fruvous
# Uncle Dave Macon
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 23:
# ------------------------------------------------------------------------------------
# Bob Dylan
# Jars Of Clay
# Billy Crystal
# Point Of Grace
# Journey
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 46:
# ------------------------------------------------------------------------------------
# Mike Oldfield
# Maura O'Connell
# Bonnie Tyler
# Morrissey
# Traffic
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 53:
# ------------------------------------------------------------------------------------
# The Donnas
# Kicked In The Head
# Robin Trower
# The Rolling Stones
# English Beat
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 124:
# ------------------------------------------------------------------------------------
# Sofia Loell
# Dan Seals
# Storyville
# Peace Of Mind
# Monaco
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 131:
# ------------------------------------------------------------------------------------
# Tarnation
# Robert Forster
# Action Swingers
# Vitamin C
# Nirvana
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 136:
# ------------------------------------------------------------------------------------
# Renee Cologne
# Billie Holiday
# Yngwie Malmsteen
# The Backstretch Boys
# Scott Walker
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 144:
# ------------------------------------------------------------------------------------
# Tesla
# Blink 182
# The Gone Jackals
# Tiger Saw
# Five Pointe O
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 159:
# ------------------------------------------------------------------------------------
# Patty Griffin
# Roger Miller
# Chris Rock
# Chris Isaak
# Luis Miguel
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 187:
# ------------------------------------------------------------------------------------
# Sleater-Kinney
# O.A.R.
# Pat Schiller
# 98 Degrees
# Little Richard
# ------------------------------------------------------------------------------------
# Training data artists for the user userid: 192:
# ------------------------------------------------------------------------------------
# Superjoint Ritual
# Inside Out
# Switchfoot
# Ben Taylor
# The Subdudes

# %%
#is_model.get_similar_items(['Shakira'])

# %%
is_model = item_similarity_recommender_py()
is_model.create(test_data, 'user_id', 'ArtistName')

# %%
#https://towardsdatascience.com/how-to-build-a-simple-song-recommender-296fcbc8c85
